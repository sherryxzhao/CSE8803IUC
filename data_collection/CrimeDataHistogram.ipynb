# %%
import pandas as pd

# %%
boston = pd.read_csv('Boston22_groundtruth.csv')

# %%
print(boston.shape)
# Out:
# (366, 122)

# %%
print(boston.head)
# Out:
# <bound method NDFrame.head of     OCCURRED_ON_DATE  AFFRAY  AIRCRAFT INCIDENTS  ANIMAL ABUSE  \
# 0         2022-01-01     0.0                 0.0           0.0
# 1         2022-01-02     0.0                 0.0           0.0
# 2         2022-01-03     0.0                 0.0           0.0
# 3         2022-01-04     0.0                 0.0           0.0
# 4         2022-01-05     0.0                 0.0           0.0
# ..               ...     ...                 ...           ...
# 361       2022-12-28     0.0                 0.0           0.0
# 362       2022-12-29     0.0                 0.0           0.0
# 363       2022-12-30     0.0                 0.0           0.0
# 364       2022-12-31     0.0                 1.0           0.0
# 365            Total    36.0                32.0          20.0
#
#      ANIMAL INCIDENTS (DOG BITES, LOST DOG, ETC)  ARSON  ASSAULT - AGGRAVATED  \
# 0                                            0.0    0.0                   7.0
# ...

# %%
import matplotlib.pyplot as plt

# %%
#%pip install matplotlib

# %%
#boston.set_index('OCCURRED_ON_DATE', inplace=True)

# drop the total column, which contains the sum of all crime types for each day
#boston.drop(columns=['Total'], inplace=True)

# create a horizontal bar chart of crime counts
boston.sum().plot.barh()

# set the title and axis labels
plt.title("Crime Counts by Type")
plt.xlabel("Count")
plt.ylabel("Crime Type")
plt.yticks(fontsize=4)

# display the plot
plt.show()

# # set the plot title and axis labels
# plt.title('Count of Each Type of Crime in 2022')
# plt.xlabel('Crime Type')
# plt.ylabel('Count')
# plt.xticks(fontsize=4)

# # display the plot
# plt.show()

# %%
print(boston.shape)
# Out:
# (366, 120)

# %%
bostoncounts = boston.sum()
top_5_crimes = bostoncounts.nlargest(5)

print("The top 5 crimes with the most count are:\n", top_5_crimes)
# Out:
# The top 5 crimes with the most count are:
#  INVESTIGATE PERSON                       15354.0
# SICK ASSIST                              10680.0
# M/V - LEAVING SCENE - PROPERTY DAMAGE     8622.0
# INVESTIGATE PROPERTY                      6818.0
# TOWED MOTOR VEHICLE                       6154.0
# dtype: float64

# %%
la = pd.read_csv('LA22_groundtruth.csv')

# %%
print(la.shape)
# Out:
# (366, 135)

# %%
print(la.head)
# Out:
# <bound method NDFrame.head of         OCCURRED_ON_DATE  ARSON  ASSAULT WITH DEADLY WEAPON ON POLICE OFFICER  \
# 0    2022-01-01 00:00:00    2.0                                           2.0
# 1    2022-01-02 00:00:00    2.0                                           1.0
# 2    2022-01-03 00:00:00    1.0                                           0.0
# 3    2022-01-04 00:00:00    1.0                                           0.0
# 4    2022-01-05 00:00:00    2.0                                           0.0
# ..                   ...    ...                                           ...
# 361  2022-12-28 00:00:00    1.0                                           0.0
# 362  2022-12-29 00:00:00    3.0                                           0.0
# 363  2022-12-30 00:00:00    1.0                                           0.0
# 364  2022-12-31 00:00:00    0.0                                           0.0
# 365                Total  530.0                                         227.0
#
# ...

# %%
#la.set_index('OCCURRED_ON_DATE', inplace=True)

# drop the total column, which contains the sum of all crime types for each day
#la.drop(columns=['Total'], inplace=True)

# create a horizontal bar chart of crime counts
#la.sum().plot(kind='bar')
la.sum().plot.barh()

# set the title and axis labels
plt.title("Crime Counts by Type")
plt.xlabel("Count")
plt.ylabel("Crime Type")
plt.yticks(fontsize=4)

# display the plot
plt.show()

# %%
print(la.shape)
# Out:
# (366, 133)

# %%
lacounts = la.sum()
top_5_crimes = lacounts.nlargest(5)

print("The top 5 crimes with the most count are:\n", top_5_crimes)
# Out:
# The top 5 crimes with the most count are:
#  VEHICLE - STOLEN            49316.0
# THEFT OF IDENTITY           42290.0
# BATTERY - SIMPLE ASSAULT    36052.0
# BURGLARY FROM VEHICLE       28370.0
# BURGLARY                    27978.0
# dtype: float64
